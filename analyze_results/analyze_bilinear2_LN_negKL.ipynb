# %%
# %pylab inline
import matplotlib.pyplot as plt
import seaborn

import os
import numpy as np
import h5py
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## bilinear2 LN negKL

# %%
savedir = '/scratch/jmj/theanomodels/experiments/mnist_ssl_vae/003_collectstats_bilinear2_negKL-mnist/VAE_lr-5_00e-04_qh-300_ph-200_ds-50_pl-3_pzl-0_ql-3_zl-2_al-1_hzl-0_nl-maxout2_opt-adam_bs-100_ep-500_idrp-0_25_reg-l2_rv-0_10_rspec-__gn-2_50_aKL-50000_aCW-50000_nKL_LN_b0-0_20_sh-1_00_bilin_cw-128_00-uid/seed-1'

# %%
ls -lh $savedir
# Out:
# total 2.7G
# -rw-rw----. 1 jmj418 jmj418 1.7K Aug 20 06:01 config.pkl
# -rw-rw----. 1 jmj418 jmj418 1.8M Aug 20 06:06 EP0-stats.h5
# -rw-rw----. 1 jmj418 jmj418  85M Aug 20 08:15 EP100-stats.h5
# -rw-rw----. 1 jmj418 jmj418 127M Aug 20 09:20 EP150-stats.h5
# -rw-rw----. 1 jmj418 jmj418 169M Aug 20 10:24 EP200-stats.h5
# -rw-rw----. 1 jmj418 jmj418 210M Aug 20 11:27 EP250-stats.h5
# -rw-rw----. 1 jmj418 jmj418 252M Aug 20 12:31 EP300-stats.h5
# -rw-rw----. 1 jmj418 jmj418 294M Aug 20 02:48 EP350-stats.h5
# -rw-rw----. 1 jmj418 jmj418 335M Aug 20 03:52 EP400-stats.h5
# -rw-rw----. 1 jmj418 jmj418 377M Aug 20 04:56 EP450-stats.h5
# -rw-rw----. 1 jmj418 jmj418 418M Aug 20 06:00 EP500-stats.h5
# -rw-rw----. 1 jmj418 jmj418  44M Aug 20 07:10 EP50-stats.h5
# -rw-rw----. 1 jmj418 jmj418 419M Aug 20 06:01 final.h5

# %%
filename = 'EP300-stats.h5'
filepath = os.path.join(savedir,filename)

# %%
def loadDataHDF5(data):
    if isinstance(data,h5py.File) or isinstance(data,h5py.Group):
        return {k:loadDataHDF5(v) for k,v in data.iteritems()}
    elif isinstance(data,h5py.Dataset):
        return data.value
    else:
        print 'unhandled datatype: %s' % type(data)

def loadHDF5(filepath):
    with h5py.File(filepath,'r') as f:
        return loadDataHDF5(f)

# %%
results = loadHDF5(filepath)
results.keys()
# Out:
# [u'train', u'valid']

# %%
train = results['train']
valid = results['valid']
#params = results['params']

# %%
def plotExperiment(results,
                   title = '',
                   keys = ['cost','bound','accuracy'],
                   funcs = [min,min,max],
                   yscales = ['linear','linear','linear'],
                   ylims = [(100,600),(100,600),(0,1)],
                   locs = ['upper right','upper right','lower right']
                   ):
    plt.figure(1,figsize=(18,4))
    for i,(key,f,yscale,ylim,loc) in enumerate(zip(keys,funcs,yscales,ylims,locs)):
        #print i,key
        plt.subplot(1,3,i+1)
        plt.plot(results['epochs'],results[key],label='best %s = %0.2f' % (key,f(results[key])))
        plt.legend(loc=loc)
        plt.yscale(yscale)
        plt.title('%s %s' % (title,key))
        if ylim is not None:
            plt.ylim(ylim)

# %%
plotExperiment(train,'train')
plt.show()
plotExperiment(valid,'valid')
plt.show()

# %%
plt.figure(1,figsize=(12,4))
plt.subplot(1,2,1)
plt.plot(train['annealKL'],label='annealKL')
plt.title('annealKL')
plt.subplot(1,2,2)
plt.plot(train['annealCW'],label='annealCW')
plt.title('annealCW')

# %%
sorted(train.keys())
# Out:
# [u'KL_L',
#  u'KL_Z_L',
#  u'KL_loggammaL',
#  u'L-q_Z_0_BN_running_mean',
#  u'L-q_Z_0_BN_running_var',
#  u'L-q_Z_1_BN_running_mean',
#  u'L-q_Z_1_BN_running_var',
#  u'L-q_h(x)_0_BN_running_mean',
#  u'L-q_h(x)_0_BN_running_var',
#  u'L-q_h(x)_1_BN_running_mean',
#  u'L-q_h(x)_1_BN_running_var',
#  u'L-q_h(x)_2_BN_running_mean',
#  u'L-q_h(x)_2_BN_running_var',
#  u'L-q_logbeta_0_BN_running_mean',
#  u'L-q_logbeta_0_BN_running_var',
#  u'NLL_L',
#  u'U-q_Z_0_BN_running_mean',
#  u'U-q_Z_0_BN_running_var',
#  u'U-q_Z_1_BN_running_mean',
#  u'U-q_Z_1_BN_running_var',
#  u'U-q_h(x)_0_BN_running_mean',
#  u'U-q_h(x)_0_BN_running_var',
#  u'U-q_h(x)_1_BN_running_mean',
#  u'U-q_h(x)_1_BN_running_var',
#  u'U-q_h(x)_2_BN_running_mean',
#  u'U-q_h(x)_2_BN_running_var',
#  u'U-q_logbeta_0_BN_running_mean',
#  u'U-q_logbeta_0_BN_running_var',
#  u'accuracy',
#  u'annealCW',
#  u'annealKL',
#  u'bound',
#  u'boundL',
#  u'boundU',
#  u'classification_loss',
#  u'cost',
#  u'epochs',
#  u'hz_L',
#  u'hz_U',
#  u'hz_W_alpha_L',
#  u'hz_W_alpha_U',
#  u'logbeta_L',
#  u'logbeta_U',
#  u'logcov2_L',
#  u'logcov2_U',
#  u'mu_L',
#  u'mu_U',
#  u'nllX_L',
#  u'nllY',
#  u'p_Z_embedded_L',
#  u'p_Z_embedded_U',
#  u'p_alpha_Z_input_W_L',
#  u'p_alpha_Z_input_W_U',
#  u'q(y|x)-q_h(x)_0_BN_running_mean',
#  u'q(y|x)-q_h(x)_0_BN_running_var',
#  u'q(y|x)-q_h(x)_1_BN_running_mean',
#  u'q(y|x)-q_h(x)_1_BN_running_var',
#  u'q(y|x)-q_h(x)_2_BN_running_mean',
#  u'q(y|x)-q_h(x)_2_BN_running_var',
#  u'q(y|x)-q_logbeta_0_BN_running_mean',
#  u'q(y|x)-q_logbeta_0_BN_running_var']

# %%
train_BNrunningstats = {k:v for k,v in train.iteritems() if 'running' in k}
sorted(train_BNrunningstats.keys())
# Out:
# [u'L-q_Z_0_BN_running_mean',
#  u'L-q_Z_0_BN_running_var',
#  u'L-q_Z_1_BN_running_mean',
#  u'L-q_Z_1_BN_running_var',
#  u'L-q_h(x)_0_BN_running_mean',
#  u'L-q_h(x)_0_BN_running_var',
#  u'L-q_h(x)_1_BN_running_mean',
#  u'L-q_h(x)_1_BN_running_var',
#  u'L-q_h(x)_2_BN_running_mean',
#  u'L-q_h(x)_2_BN_running_var',
#  u'L-q_logbeta_0_BN_running_mean',
#  u'L-q_logbeta_0_BN_running_var',
#  u'U-q_Z_0_BN_running_mean',
#  u'U-q_Z_0_BN_running_var',
#  u'U-q_Z_1_BN_running_mean',
#  u'U-q_Z_1_BN_running_var',
#  u'U-q_h(x)_0_BN_running_mean',
#  u'U-q_h(x)_0_BN_running_var',
#  u'U-q_h(x)_1_BN_running_mean',
#  u'U-q_h(x)_1_BN_running_var',
#  u'U-q_h(x)_2_BN_running_mean',
#  u'U-q_h(x)_2_BN_running_var',
#  u'U-q_logbeta_0_BN_running_mean',
#  u'U-q_logbeta_0_BN_running_var',
#  u'q(y|x)-q_h(x)_0_BN_running_mean',
#  u'q(y|x)-q_h(x)_0_BN_running_var',
#  u'q(y|x)-q_h(x)_1_BN_running_mean',
#  u'q(y|x)-q_h(x)_1_BN_running_var',
#  u'q(y|x)-q_h(x)_2_BN_running_mean',
#  u'q(y|x)-q_h(x)_2_BN_running_var',
#  u'q(y|x)-q_logbeta_0_BN_running_mean',
#  u'q(y|x)-q_logbeta_0_BN_running_var']

# %%
prefixes = ['q(y|x)','L','U']
d = {p:{} for p in prefixes}
for k,v in train_BNrunningstats.iteritems():
    for p in prefixes:
        if k[:len(p)]==p:
            d[p][k[len(p)+1:]] = v
            
d2 = set(k for k in d[p].keys() for p in d.keys())
d2 = {k:{p:d[p][k] for p in d.keys() if k in d[p].keys()} for k in d2 }

# %%
#means
for k,v in sorted(d2.iteritems(),key=lambda x:x[0]):
    if 'mean' in k:
        U = v['U']
        L = v['L']
        diff = np.abs(L-U)
        avgdiff = diff.mean(axis=1)
        p10diff = np.percentile(diff,20,axis=1)
        p90diff = np.percentile(diff,80,axis=1)
        plt.plot(avgdiff,label=k)
        plt.fill_between(np.arange(len(avgdiff)),p10diff,p90diff,color='b',alpha=0.2)
plt.legend(loc='upper left')
plt.title('|L-U|')
plt.ylim(0,2)
# Out:
# (0, 2)
# /usr/local/pkg/python/2.7/lib/python2.7/site-packages/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':

# %%
#means
for k,v in sorted(d2.iteritems(),key=lambda x:x[0]):
    if 'var' in k:
        U = v['U']
        L = v['L']
        diff = np.abs(L**0.5-U**0.5)
        avgdiff = diff.mean(axis=1)
        p10diff = np.percentile(diff,10,axis=1)
        p90diff = np.percentile(diff,90,axis=1)
        plt.plot(avgdiff,label=k)
        plt.fill_between(np.arange(len(avgdiff)),p10diff,p90diff,color='b',alpha=0.2)
#plt.yscale('log')
plt.legend(loc='upper left')
plt.title('|L^0.5-U^0.5|')
plt.ylim(0,7)
# Out:
# (0, 7)

# %%
#means
for k,v in sorted(d2.iteritems(),key=lambda x:x[0]):
    if 'running_mean' in k and 'q_logbeta' in k:
        U = v['U']
        L = v['L']
        diff = np.abs(U-L)
        mediandiff = np.percentile(diff,50,axis=1)
        p05diff = np.percentile(diff,5,axis=1)
        p10diff = np.percentile(diff,10,axis=1)
        p25diff = np.percentile(diff,25,axis=1)
        p40diff = np.percentile(diff,40,axis=1)
        p60diff = np.percentile(diff,60,axis=1)
        p75diff = np.percentile(diff,75,axis=1)
        p90diff = np.percentile(diff,90,axis=1)
        p95diff = np.percentile(diff,95,axis=1)
        plt.plot(mediandiff,label=k)
        plt.fill_between(np.arange(len(avgdiff)),p05diff,p95diff,color='b',alpha=0.1)
        plt.fill_between(np.arange(len(avgdiff)),p10diff,p90diff,color='b',alpha=0.1)
        plt.fill_between(np.arange(len(avgdiff)),p25diff,p75diff,color='b',alpha=0.1)
        plt.fill_between(np.arange(len(avgdiff)),p40diff,p60diff,color='b',alpha=0.1)
#plt.yscale('log')
plt.legend(loc='upper left')
plt.title('U-L percentiles')

# %%
#means
for k,v in sorted(d2.iteritems(),key=lambda x:x[0]):
    if 'running_var' in k and 'q_logbeta' in k:
        U = v['U']
        L = v['L']
        diff = U**0.5-L**0.5
        mediandiff = np.percentile(diff,50,axis=1)
        p05diff = np.percentile(diff,5,axis=1)
        p10diff = np.percentile(diff,10,axis=1)
        p25diff = np.percentile(diff,25,axis=1)
        p40diff = np.percentile(diff,40,axis=1)
        p60diff = np.percentile(diff,60,axis=1)
        p75diff = np.percentile(diff,75,axis=1)
        p90diff = np.percentile(diff,90,axis=1)
        p95diff = np.percentile(diff,95,axis=1)
        plt.plot(mediandiff,label=k)
        plt.fill_between(np.arange(len(avgdiff)),p05diff,p95diff,color='b',alpha=0.1)
        plt.fill_between(np.arange(len(avgdiff)),p10diff,p90diff,color='b',alpha=0.1)
        plt.fill_between(np.arange(len(avgdiff)),p25diff,p75diff,color='b',alpha=0.1)
        plt.fill_between(np.arange(len(avgdiff)),p40diff,p60diff,color='b',alpha=0.1)
#plt.yscale('log')
plt.legend(loc='upper left')
plt.title('U^0.5-L^0.5 percentiles')

# %%
train_logbetas = {k:v for k,v in train.iteritems() if 'logbeta' in k and 'running' not in k}
sorted(train_logbetas.keys())
# Out:
# [u'logbeta_L', u'logbeta_U']

# %%
import scipy

# %%
#entropyL = scipy.stats.loggamma.entropy(np.exp(vals['train_logbetas']['logbeta_L']))

# %%
#entropyU = scipy.stats.loggamma.entropy(np.exp(vals['train_logbetas']['logbeta_U']))

# %%
def moving_average(a, n=3) :
    ret = np.cumsum(a, dtype=float)
    ret[n:] = ret[n:] - ret[:-n]
    return ret[n - 1:] / n

# %%
#plt.plot(moving_average(entropyL.sum(axis=1),n=100),label='L')
#plt.plot(moving_average(entropyU.sum(axis=1),n=100),label='U')
#plt.legend()
#plt.title('train loggamma entropy')

# %%
def reshape(x,batch_size=100):
    y = []
    n = len(x)/batch_size
    for i in range(n):
        y.append(x[batch_size*i:batch_size*(i+1)].reshape(1,batch_size,-1))
    y = np.vstack(y)
    return y

def plotPercentiles(x=None,y=None,color='b',alpha=0.2,label=None,linewidth=1.):
    if y==None:
        xvals = None
        yvals = x
    else:
        xvals = x
        yvals = y
    p05_norm = np.percentile(yvals,5,axis=1)
    p10_norm = np.percentile(yvals,10,axis=1)
    p25_norm = np.percentile(yvals,25,axis=1)
    p50_norm = np.percentile(yvals,50,axis=1)
    p75_norm = np.percentile(yvals,75,axis=1)
    p90_norm = np.percentile(yvals,90,axis=1)
    p95_norm = np.percentile(yvals,95,axis=1)
    
    if xvals is None:
        xvals = np.arange(len(p50_norm))

    plt.plot(xvals,p50_norm,color=color,label=label,linewidth=linewidth)
    plt.fill_between(xvals,p05_norm,p95_norm,color=color,alpha=alpha)
    plt.fill_between(xvals,p10_norm,p90_norm,color=color,alpha=alpha)
    plt.fill_between(xvals,p25_norm,p75_norm,color=color,alpha=alpha)

# %%
for k in range(10):
    plotPercentiles(reshape(sortedL)[:,:,k],label='k',alpha=0.05,linewidth=0.5)
plt.yscale('log')
#plt.xlim(0,500)
plt.ylim(1e-2,1e2)
plt.title('train beta L')

# %%
plt.figure(1,figsize=(9,8))
maxbetaL = moving_average(np.exp(train_logbetas['logbeta_L']).max(axis=1),n=500)
maxbetaU = moving_average(np.exp(train_logbetas['logbeta_U']).max(axis=1),n=500)
minbetaL = moving_average(np.exp(train_logbetas['logbeta_L']).min(axis=1),n=500)
minbetaU = moving_average(np.exp(train_logbetas['logbeta_U']).min(axis=1),n=500)
plt.plot(maxbetaL,label='L',color='g')
plt.plot(maxbetaU,label='U',color='b')
plt.plot(minbetaL,color='g')
plt.plot(minbetaU,color='b')
plt.legend()
plt.yscale('log')
#plt.ylim(0,1)
plt.title('train max/min beta')

# %%
#plt.figure(1,figsize=(16,6))

sortedL = np.sort(np.exp(train['logbeta_L']),axis=1)
#plt.subplot(1,2,1)
for i in range(10):
    x = moving_average(sortedL[:,i],n=500)
    plt.plot(x,label='%s: %0.2f' % (i,x[-1]),color='b',linewidth=0.5)
#plt.plot()
plt.yscale('log')
plt.title('train beta L')
plt.legend()
plt.ylim(1e-2,1e2)
plt.show()

for k in range(10):
    vals = reshape(sortedL)[:,:,k]
    plotPercentiles(vals,label='%s: %0.2f'%(k,vals[-1,:].mean()),alpha=0.05,linewidth=0.5)
plt.yscale('log')
#plt.xlim(0,500)
plt.ylim(1e-2,1e2)
plt.title('train beta L')
plt.legend()
plt.show()

# %%
sortedU = np.sort(np.exp(train['logbeta_U']),axis=1)
#plt.subplot(1,2,1)
for i in range(10):
    x = moving_average(sortedU[:,i],n=500)
    plt.plot(x,label='%s: %0.2f' % (i,x[-1]),color='g',linewidth=0.5)
#plt.plot()
plt.yscale('log')
plt.title('train beta U')
plt.legend()
plt.show()

for k in range(10):
    vals = reshape(sortedU)[:,:,k]
    plotPercentiles(vals,label='%s: %0.2f'%(k,vals[-1,:].mean()),color='g',alpha=0.05,linewidth=0.5)
plt.yscale('log')
#plt.xlim(0,500)
plt.ylim(1e-2,1e2)
plt.title('train beta U')
plt.legend()
plt.show()

# %%
#plt.figure(1,figsize=(16,6))

sortedU = np.sort(np.exp(valid['logbeta_U']),axis=1)
#plt.subplot(1,2,1)
for i in range(10):
    x = moving_average(sortedU[:,i],n=100)
    plt.plot(x,label='%s: %0.2f' % (i,x[-1]),color='g',linewidth=0.5)
#plt.plot()
plt.yscale('log')
plt.title('valid beta U')
plt.legend()
plt.show()

for k in range(10):
    vals = reshape(sortedU)[:,:,k]
    plotPercentiles(valid['epochs'],vals,label='%s: %0.2f'%(k,vals[-1,:].mean()),color='g',alpha=0.05,linewidth=0.5)
plt.yscale('log')
#plt.xlim(0,500)
plt.ylim(1e-2,1e2)
plt.title('valid beta U')
plt.legend()
plt.show()
# Out:
# -c:10: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.

# %%
#plt.figure(1,figsize=(16,6))

sortedL = np.sort(np.exp(valid['logbeta_L']),axis=1)
#plt.subplot(1,2,1)
for i in range(10):
    x = moving_average(sortedL[:,i],n=100)
    plt.plot(x,label='%s: %0.2f' % (i,x[-1]),color='b',linewidth=0.5)
#plt.plot()
plt.yscale('log')
plt.title('valid beta L')
plt.legend()
plt.show()

for k in range(10):
    vals = reshape(sortedL)[:,:,k]
    plotPercentiles(valid['epochs'],vals,label='%s: %0.2f'%(k,vals[-1,:].mean()),color='b',alpha=0.05,linewidth=0.5)
plt.yscale('log')
#plt.xlim(0,500)
plt.ylim(1e-2,1e2)
plt.title('valid beta L')
plt.legend()
plt.show()

# %% [markdown]
# ## Dirichlet Histograms

# %%
b = 0.2*np.ones(10)

for i in range(1,22,4):
    b[0] = i
    a = np.random.dirichlet(b,size=10000)
    plt.hist(a[:,0],bins=np.arange(0,1,0.01),label='%s'%i,alpha=0.4)
plt.legend(loc='upper left')
plt.xlim(0,1)
# Out:
# (0, 1)

# %% [markdown]
# ## Dirichlet with Sharpening

# %%
b = 0.2*np.ones(10)
b[0] = 5.

for i in range(1,5):
    u = []
    for j in b:
        u.append(scipy.stats.loggamma.rvs(j,size=10000))
    u = np.vstack(u).T
    a = np.exp(i*u)/np.sum(np.exp(i*u),axis=1,keepdims=True)
    plt.hist(a[:,0],bins=np.arange(0,1,0.01),label='%s, beta=%s'%(i,b[0]*i),alpha=0.4)
plt.legend(loc='upper left')
plt.xlim(0,1)
# Out:
# (0, 1)

# %% [markdown]
# ## bilinear operations - inference

# %%
hzU = train['hz_U']
hzWaU = train['hz_W_alpha_U']
hzU_reshaped = reshape(hzU)
hzWaU_reshaped = reshape(hzWaU)
plotPercentiles(hzU_reshaped.reshape(hzU_reshaped.shape[0],-1),color='b',label='pre-bilinear')
plotPercentiles(hzWaU_reshaped.reshape(hzWaU_reshaped.shape[0],-1),color='g',label='post-bilinear')
plt.legend()
plt.title('train U - inference')

# %%
plotPercentiles(hzWaU_reshaped.reshape(hzWaU_reshaped.shape[0],-1)-hzU_reshaped.reshape(hzU_reshaped.shape[0],-1),label='hzU-hzWaU')
plt.legend()
plt.title('train U - difference')

# %%
hzL = train['hz_L']
hzWaL = train['hz_W_alpha_L']
hzL_reshaped = reshape(hzL)
hzWaL_reshaped = reshape(hzWaL)
plotPercentiles(hzL_reshaped.reshape(hzL_reshaped.shape[0],-1),color='b',label='pre-bilinear')
plotPercentiles(hzWaL_reshaped.reshape(hzWaL_reshaped.shape[0],-1),color='g',label='post-bilinear')
plt.legend()
plt.title('train L - inference')

# %%
plotPercentiles(hzWaL_reshaped.reshape(hzWaL_reshaped.shape[0],-1)-hzL_reshaped.reshape(hzL_reshaped.shape[0],-1),label='hzL-hzWaL')
plt.legend()
plt.title('train L - difference')

# %%
nvalid = 31
hzU = valid['hz_U']
hzWaU = valid['hz_W_alpha_U']
print hzU.shape
plotPercentiles(reshape(hzU).reshape(nvalid,-1),color='b',label='pre-bilinear')
plotPercentiles(reshape(hzWaU).reshape(nvalid,-1),color='g',label='post-bilinear')
plt.legend()
plt.title('valid U - inference')
# Out:
# (3100, 300)

# %%
plotPercentiles(reshape(hzWaU).reshape(nvalid,-1)-reshape(hzU).reshape(nvalid,-1),label='hzU-hzWaU')
plt.legend()
plt.title('valid U - difference')

# %%
hzL = valid['hz_L']
hzWaL = valid['hz_W_alpha_L']
plotPercentiles(reshape(hzL).reshape(nvalid,-1),color='b',label='pre-bilinear')
plotPercentiles(reshape(hzWaL).reshape(nvalid,-1),color='g',label='post-bilinear')
plt.legend()
plt.title('valid U - inference')

# %% [markdown]
# ## bilinear operations - generative

# %%
ntrain = 301
pzU = train['p_Z_embedded_U']
pzWaU = train['p_alpha_Z_input_W_U']
plotPercentiles(reshape(pzU).reshape(ntrain,-1),color='b',label='pre-bilinear')
plotPercentiles(reshape(pzWaU).reshape(ntrain,-1),color='g',label='post-bilinear')
plt.legend()
plt.title('train U - generative')

# %%
plotPercentiles(reshape(pzWaU).reshape(ntrain,-1)-reshape(pzU).reshape(ntrain,-1),label='pzU-pzWaU')
plt.legend()
plt.title('train U - difference')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-82-cc63e227a0db> in <module>()
# ----> 1 plotPercentiles(reshape(pzWaU).reshape(ntrain,-1)-reshape(pzU).reshape(ntrain,-1),label='pzU-pzWaU')
#       2 plt.legend()
#       3 plt.title('train U - difference')
#
# ValueError: operands could not be broadcast together with shapes (301,20000) (301,5000)

# %%
pzL = train['p_Z_embedded_L']
pzWaL = train['p_alpha_Z_input_W_L']
plotPercentiles(reshape(pzL).reshape(ntrain,-1),color='b',label='pre-bilinear')
plotPercentiles(reshape(pzWaL).reshape(ntrain,-1),color='g',label='post-bilinear')
plt.legend()
plt.title('train L - generative')

# %%
plotPercentiles(reshape(pzWaL).reshape(ntrain,-1)-reshape(pzL).reshape(ntrain,-1),label='pzL-pzWaL')
plt.legend()
plt.title('train L - difference')

# %% [markdown]
# ## Z

# %%
muL = train['mu_L']
muU = train['mu_U']
print muU.shape
# Out:
# (30100, 50)

# %%
sorted_muL = muL[:,np.argsort(muL[-1])]
for i in range(muL.shape[1]):
    plt.plot(moving_average(sorted_muL[:,i],n=100),color='b',linewidth=0.1)

# %%
sorted_muU = muU[:,np.argsort(muU[-1])]
for i in range(muU.shape[1]):
    plt.plot(moving_average(sorted_muU[:,i],n=100),color='g',linewidth=0.1)

# %%
logcov2L = train['logcov2_L']
logcov2U = train['logcov2_U']
print logcov2U.shape
sigmaU = np.exp(0.5*logcov2U)
sigmaL = np.exp(0.5*logcov2L)
# Out:
# (30100, 50)

# %%
KL_U = 0.5*(np.exp(logcov2U)+muU**2.0-1.0-logcov2U)
KL_L = 0.5*(np.exp(logcov2L)+muL**2.0-1.0-logcov2L)

# %%
plt.figure(1,figsize=(16,6))

plt.subplot(1,2,1)
sorted_KL_U = np.sort(KL_U,axis=1)
for i in range(KL_U.shape[1]):
    plt.plot(moving_average(sorted_KL_U[:,i],n=100),color='g',linewidth=0.5)
plt.title('KL(Z)_U')
plt.ylim(0,9)

plt.subplot(1,2,2)
sorted_KL_L = np.sort(KL_L,axis=1)
for i in range(KL_L.shape[1]):
    plt.plot(moving_average(sorted_KL_L[:,i],n=100),color='b',linewidth=0.5)
plt.title('KL(Z)_L')
plt.ylim(0,9)
# Out:
# (0, 9)

# %%
sorted_KL_U = np.sort(KL_U,axis=1)
for i in range(KL_U.shape[1]):
    plt.plot(moving_average(sorted_KL_U[:,i],n=100),color='g',linewidth=0.5)
plt.title('KL(Z)_U')
plt.ylim(0,9)
plt.show()

sorted_KL_L = np.sort(KL_L,axis=1)
for i in range(KL_L.shape[1]):
    plt.plot(moving_average(sorted_KL_L[:,i],n=100),color='b',linewidth=0.5)
plt.title('KL(Z)_L')
plt.ylim(0,9)
plt.show()

# %%
sorted_KL_U = np.sort(KL_U,axis=1)
for k in range(KL_U.shape[1]):
    vals = reshape(sorted_KL_U)[:,:,k]
    plotPercentiles(vals,color='g',alpha=0.05,linewidth=0.5)
#plt.xlim(0,500)
plt.ylim(0,9)
plt.title('KL(Z)_U')
plt.legend()
plt.show()

sorted_KL_L = np.sort(KL_L,axis=1)
for k in range(KL_L.shape[1]):
    vals = reshape(sorted_KL_L)[:,:,k]
    plotPercentiles(vals,color='b',alpha=0.05,linewidth=0.5)
#plt.xlim(0,500)
plt.ylim(0,9)
plt.title('KL(Z)_L')
plt.legend()
plt.show()

# %%
plt.figure(1,figsize=(16,6))

plt.subplot(1,2,1)
sorted_KL_U = KL_U[:,np.argsort(KL_U[-1])]
for i in range(KL_U.shape[1]):
    plt.plot(moving_average(sorted_KL_U[:,i],n=100),color='g',linewidth=0.5)
activeKL_U = np.sum(KL_U > 0.1,axis=1)
activeKL_U = moving_average(activeKL_U,n=100)
plt.plot(activeKL_U,color='k',label='# active KLs > 0.2')
plt.title('train KL(Z)_U')
plt.ylim(0,12)
plt.legend()

plt.subplot(1,2,2)
sorted_KL_L = KL_L[:,np.argsort(KL_L[-1])]
for i in range(KL_L.shape[1]):
    plt.plot(moving_average(sorted_KL_L[:,i],n=100),color='b',linewidth=0.5)
activeKL_L = np.sum(KL_L > 0.1,axis=1)
activeKL_L = moving_average(activeKL_L,n=100)
plt.plot(activeKL_L,color='k',label='# active KLs > 0.2')
plt.title('train KL(Z)_L')
plt.ylim(0,12)
plt.legend()

# %%
plt.figure(1,figsize=(16,6))

muL = valid['mu_L']
muU = valid['mu_U']
logcov2L = valid['logcov2_L']
logcov2U = valid['logcov2_U']
sigmaU = np.exp(0.5*logcov2U)
sigmaL = np.exp(0.5*logcov2L)
KL_U = 0.5*(np.exp(logcov2U)+muU**2.0-1.0-logcov2U)
KL_L = 0.5*(np.exp(logcov2L)+muL**2.0-1.0-logcov2L)

plt.subplot(1,2,1)
sorted_KL_U = KL_U[:,np.argsort(KL_U[-1])]
for i in range(KL_U.shape[1]):
    plt.plot(moving_average(sorted_KL_U[:,i],n=100),color='g',linewidth=0.5)
activeKL_U = np.sum(KL_U > 0.1,axis=1)
activeKL_U = moving_average(activeKL_U,n=10)
plt.plot(activeKL_U,color='k',label='# active KLs > 0.2')
plt.title('valid KL(Z)_U')
plt.ylim(0,12)
plt.legend()

plt.subplot(1,2,2)
sorted_KL_L = KL_L[:,np.argsort(KL_L[-1])]
for i in range(KL_L.shape[1]):
    plt.plot(moving_average(sorted_KL_L[:,i],n=100),color='b',linewidth=0.5)
activeKL_L = np.sum(KL_L > 0.1,axis=1)
activeKL_L = moving_average(activeKL_L,n=10)
plt.plot(activeKL_L,color='k',label='# active KLs > 0.2')
plt.title('valid KL(Z)_L')
plt.ylim(0,12)
plt.legend()
